# %%
import cv2
import mediapipe as mp
import numpy as np
import os

# %%
print("Khushi")
# Out:
# Khushi

# %%
import cv2

import mediapipe as mp
import numpy as np
import os



# Initialize MediaPipe Hands and Face Mesh models
mp_hands = mp.solutions.hands
mp_drawing = mp.solutions.drawing_utils
mp_face_mesh = mp.solutions.face_mesh

# %%
# Function to blackout the background and keep only the hand movements
def blackout_background(video_path, output_path):
    hands = mp_hands.Hands(static_image_mode=False, max_num_hands=2, min_detection_confidence=0.5)
    cap = cv2.VideoCapture(video_path)

    # Get video details
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')

    # Video writer to save the processed video
    out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert the image to RGB as MediaPipe expects this format
        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Get hand landmarks
        result = hands.process(image_rgb)

        # Create a blackout frame (all black)
        black_frame = np.zeros_like(frame)

        if result.multi_hand_landmarks:
            for hand_landmarks in result.multi_hand_landmarks:
                # Draw the hand landmarks on the black frame
                mp_drawing.draw_landmarks(
                    black_frame,
                    hand_landmarks,
                    mp_hands.HAND_CONNECTIONS,
                    mp_drawing.DrawingSpec(color=(255, 255, 255), thickness=2, circle_radius=2)
                )

        # Write the black_frame with only hands visible to output video
        out.write(black_frame)

    cap.release()
    out.release()
    hands.close()

# %%
# Example usage: Process the dictionary videos
dictionary_videos_path = "D:/Ace/7th sem files/1. REU/dataprep2"  # Replace with actual path
blackout_videos_output_path = "D:/Ace/7th sem files/1. REU/dataprep2blackout"  # Replace with actual output folder

# %%
# Iterate over all dictionary videos and process each
for video_file in os.listdir(dictionary_videos_path):
    if video_file.endswith(".mp4"):  # Process only .mp4 videos (adjust if necessary)
        video_path = os.path.join(dictionary_videos_path, video_file)
        output_path = os.path.join(blackout_videos_output_path, video_file)
        blackout_background(video_path, output_path)

print("All dictionary videos processed and saved in the D:/Ace/7th sem files/1. REU/dataprep2blackout")
# Out:
# All dictionary videos processed and saved in the D:/Ace/7th sem files/1. REU/dataprep2blackout

# %%
# Step 1: Frame Extraction
def extract_frames(video_path, frame_rate=1):
    print(f"Extracting frames from {video_path}...")
    cap = cv2.VideoCapture(video_path)
    frames = []
    count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        if count % frame_rate == 0:
            frames.append(frame)
        count += 1
    cap.release()
    print(f"Extracted {len(frames)} frames from {video_path}.")
    return frames

# Step 2: Normalization & Resizing
def preprocess_frame(frame, size=(224, 224)):
    transform = transforms.Compose([
        transforms.ToPILImage(),
        transforms.Resize(size),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
    frame = transform(frame)
    # print("Frame preprocessed.")
    return frame

# Step 3: Augmentation (optional)
def augment_frames(frames):
    print("Augmenting frames...")
    transform = transforms.Compose([
        transforms.RandomRotation(10),
        transforms.RandomHorizontalFlip(),
        transforms.RandomResizedCrop(size=(224, 224), scale=(0.8, 1.0))
    ])
    augmented_frames = []
    for frame in frames:
        frame = transform(frame)
        augmented_frames.append(frame)
    print(f"Augmented {len(augmented_frames)} frames.")
    return augmented_frames

# Step 4: Label Assignment
# def get_label_from_filename(filename):
#     label = filename.split()[1].split('.')[0]
#     print(f"Assigned label '{label}' to {filename}.")
#     return label

def get_label_from_filename(filename):
    # Assuming the label is the part before the extension (e.g., "aadhar_card.mp4")
    label = filename.split('.')[0]  # Get the filename without the extension
    print(f"Assigned label '{label}' to {filename}.")
    return label


# Main Preprocessing Function
def preprocess_videos(directory):
    print(f"Preprocessing videos in directory: {directory}")
    video_data = []
    labels = []
    for filename in os.listdir(directory):
        if filename.endswith(".mp4"):
            video_path = os.path.join(directory, filename)
            frames = extract_frames(video_path)
            frames = [preprocess_frame(frame) for frame in frames]
            frames = augment_frames(frames)  # Optional
            label = get_label_from_filename(filename)
            video_data.append(frames)
            labels.append(label)
    print("Preprocessing complete.")
    return video_data, labels


import torch
from torchvision import transforms


# Example usage
video_directory = blackout_videos_output_path
video_data, labels = preprocess_videos(video_directory)

# Save preprocessed data for later use
torch.save(video_data, 'video_data.pt')
torch.save(labels, 'labels.pt')
print("Data saved.")
# Out:
# Preprocessing videos in directory: D:/Ace/7th sem files/1. REU/dataprep2blackout
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aadhar_card.mp4...
# Extracted 94 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aadhar_card.mp4.
# Augmenting frames...
# Augmented 94 frames.
# Assigned label 'aadhar_card' to aadhar_card.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accelerate.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accelerate.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'accelerate' to accelerate.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_grants 2.mp4...
# Extracted 64 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_grants 2.mp4.
# Augmenting frames...
# Augmented 64 frames.
# Assigned label 'accessibility_grants 2' to accessibility_grants 2.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_grants.mp4...
# Extracted 89 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_grants.mp4.
# Augmenting frames...
# Augmented 89 frames.
# Assigned label 'accessibility_grants' to accessibility_grants.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_resource_centre.mp4...
# Extracted 58 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_resource_centre.mp4.
# Augmenting frames...
# Augmented 58 frames.
# Assigned label 'accessibility_resource_centre' to accessibility_resource_centre.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_testing.mp4...
# Extracted 58 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_testing.mp4.
# Augmenting frames...
# Augmented 58 frames.
# Assigned label 'accessibility_testing' to accessibility_testing.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_tourism.mp4...
# Extracted 61 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessibility_tourism.mp4.
# Augmenting frames...
# Augmented 61 frames.
# Assigned label 'accessibility_tourism' to accessibility_tourism.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_banking.mp4...
# Extracted 56 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_banking.mp4.
# Augmenting frames...
# Augmented 56 frames.
# Assigned label 'accessible_banking' to accessible_banking.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_design_pattern.mp4...
# Extracted 93 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_design_pattern.mp4.
# Augmenting frames...
# Augmented 93 frames.
# Assigned label 'accessible_design_pattern' to accessible_design_pattern.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_housing.mp4...
# Extracted 45 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accessible_housing.mp4.
# Augmenting frames...
# Augmented 45 frames.
# Assigned label 'accessible_housing' to accessible_housing.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accidental.mp4...
# Extracted 39 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\accidental.mp4.
# Augmenting frames...
# Augmented 39 frames.
# Assigned label 'accidental' to accidental.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\acqueduct.mp4...
# Extracted 99 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\acqueduct.mp4.
# Augmenting frames...
# Augmented 99 frames.
# Assigned label 'acqueduct' to acqueduct.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\actual.mp4...
# Extracted 24 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\actual.mp4.
# Augmenting frames...
# Augmented 24 frames.
# Assigned label 'actual' to actual.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adaptive.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adaptive.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'adaptive' to adaptive.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adaptive_software.mp4...
# Extracted 46 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adaptive_software.mp4.
# Augmenting frames...
# Augmented 46 frames.
# Assigned label 'adaptive_software' to adaptive_software.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adjust.mp4...
# Extracted 41 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adjust.mp4.
# Augmenting frames...
# Augmented 41 frames.
# Assigned label 'adjust' to adjust.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\admission.mp4...
# Extracted 66 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\admission.mp4.
# Augmenting frames...
# Augmented 66 frames.
# Assigned label 'admission' to admission.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adquate.mp4...
# Extracted 91 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\adquate.mp4.
# Augmenting frames...
# Augmented 91 frames.
# Assigned label 'adquate' to adquate.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aerodynamics.mp4...
# Extracted 38 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aerodynamics.mp4.
# Augmenting frames...
# Augmented 38 frames.
# Assigned label 'aerodynamics' to aerodynamics.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\agencies.mp4...
# Extracted 42 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\agencies.mp4.
# Augmenting frames...
# Augmented 42 frames.
# Assigned label 'agencies' to agencies.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\agility.mp4...
# Extracted 23 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\agility.mp4.
# Augmenting frames...
# Augmented 23 frames.
# Assigned label 'agility' to agility.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\airline.mp4...
# Extracted 51 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\airline.mp4.
# Augmenting frames...
# Augmented 51 frames.
# Assigned label 'airline' to airline.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_bag.mp4...
# Extracted 76 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_bag.mp4.
# Augmenting frames...
# Augmented 76 frames.
# Assigned label 'air_bag' to air_bag.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_brake.mp4...
# Extracted 64 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_brake.mp4.
# Augmenting frames...
# Augmented 64 frames.
# Assigned label 'air_brake' to air_brake.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_vents.mp4...
# Extracted 87 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\air_vents.mp4.
# Augmenting frames...
# Augmented 87 frames.
# Assigned label 'air_vents' to air_vents.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\algorithm.mp4...
# Extracted 44 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\algorithm.mp4.
# Augmenting frames...
# Augmented 44 frames.
# Assigned label 'algorithm' to algorithm.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\alternate_formats.mp4...
# Extracted 58 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\alternate_formats.mp4.
# Augmenting frames...
# Augmented 58 frames.
# Assigned label 'alternate_formats' to alternate_formats.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\amplification.mp4...
# Extracted 63 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\amplification.mp4.
# Augmenting frames...
# Augmented 63 frames.
# Assigned label 'amplification' to amplification.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\amplify.mp4...
# Extracted 63 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\amplify.mp4.
# Augmenting frames...
# Augmented 63 frames.
# Assigned label 'amplify' to amplify.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\apart.mp4...
# Extracted 95 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\apart.mp4.
# Augmenting frames...
# Augmented 95 frames.
# Assigned label 'apart' to apart.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appear.mp4...
# Extracted 129 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appear.mp4.
# Augmenting frames...
# Augmented 129 frames.
# Assigned label 'appear' to appear.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appraisals.mp4...
# Extracted 67 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appraisals.mp4.
# Augmenting frames...
# Augmented 67 frames.
# Assigned label 'appraisals' to appraisals.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appraisal_period.mp4...
# Extracted 39 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\appraisal_period.mp4.
# Augmenting frames...
# Augmented 39 frames.
# Assigned label 'appraisal_period' to appraisal_period.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\approach.mp4...
# Extracted 36 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\approach.mp4.
# Augmenting frames...
# Augmented 36 frames.
# Assigned label 'approach' to approach.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\arial_tramway.mp4...
# Extracted 54 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\arial_tramway.mp4.
# Augmenting frames...
# Augmented 54 frames.
# Assigned label 'arial_tramway' to arial_tramway.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\arrival.mp4...
# Extracted 30 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\arrival.mp4.
# Augmenting frames...
# Augmented 30 frames.
# Assigned label 'arrival' to arrival.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\assembly.mp4...
# Extracted 65 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\assembly.mp4.
# Augmenting frames...
# Augmented 65 frames.
# Assigned label 'assembly' to assembly.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\assistive_technology.mp4...
# Extracted 45 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\assistive_technology.mp4.
# Augmenting frames...
# Augmented 45 frames.
# Assigned label 'assistive_technology' to assistive_technology.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\attribute.mp4...
# Extracted 68 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\attribute.mp4.
# Augmenting frames...
# Augmented 68 frames.
# Assigned label 'attribute' to attribute.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\audio_navigation.mp4...
# Extracted 69 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\audio_navigation.mp4.
# Augmenting frames...
# Augmented 69 frames.
# Assigned label 'audio_navigation' to audio_navigation.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\auditory.mp4...
# Extracted 36 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\auditory.mp4.
# Augmenting frames...
# Augmented 36 frames.
# Assigned label 'auditory' to auditory.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\augmentative_and_alternative_communication.mp4...
# Extracted 100 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\augmentative_and_alternative_communication.mp4.
# Augmenting frames...
# Augmented 100 frames.
# Assigned label 'augmentative_and_alternative_communication' to augmentative_and_alternative_communication.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\automobile.mp4...
# Extracted 67 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\automobile.mp4.
# Augmenting frames...
# Augmented 67 frames.
# Assigned label 'automobile' to automobile.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\autonomous_vehicle.mp4...
# Extracted 64 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\autonomous_vehicle.mp4.
# Augmenting frames...
# Augmented 64 frames.
# Assigned label 'autonomous_vehicle' to autonomous_vehicle.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\average.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\average.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'average' to average.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aviation.mp4...
# Extracted 48 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\aviation.mp4.
# Augmenting frames...
# Augmented 48 frames.
# Assigned label 'aviation' to aviation.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\await.mp4...
# Extracted 30 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\await.mp4.
# Augmenting frames...
# Augmented 30 frames.
# Assigned label 'await' to await.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\axle.mp4...
# Extracted 69 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\axle.mp4.
# Augmenting frames...
# Augmented 69 frames.
# Assigned label 'axle' to axle.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\butcher.mp4...
# Extracted 59 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\butcher.mp4.
# Augmenting frames...
# Augmented 59 frames.
# Assigned label 'butcher' to butcher.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\dedication.mp4...
# Extracted 63 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\dedication.mp4.
# Augmenting frames...
# Augmented 63 frames.
# Assigned label 'dedication' to dedication.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\insight.mp4...
# Extracted 35 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\insight.mp4.
# Augmenting frames...
# Augmented 35 frames.
# Assigned label 'insight' to insight.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\underground_utility.mp4...
# Extracted 174 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\underground_utility.mp4.
# Augmenting frames...
# Augmented 174 frames.
# Assigned label 'underground_utility' to underground_utility.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\underwent.mp4...
# Extracted 111 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\underwent.mp4.
# Augmenting frames...
# Augmented 111 frames.
# Assigned label 'underwent' to underwent.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\universal.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\universal.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'universal' to universal.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\unused.mp4...
# Extracted 72 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\unused.mp4.
# Augmenting frames...
# Augmented 72 frames.
# Assigned label 'unused' to unused.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\upright_monument.mp4...
# Extracted 63 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\upright_monument.mp4.
# Augmenting frames...
# Augmented 63 frames.
# Assigned label 'upright_monument' to upright_monument.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\urban_development.mp4...
# Extracted 96 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\urban_development.mp4.
# Augmenting frames...
# Augmented 96 frames.
# Assigned label 'urban_development' to urban_development.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\urban_renewal.mp4...
# Extracted 105 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\urban_renewal.mp4.
# Augmenting frames...
# Augmented 105 frames.
# Assigned label 'urban_renewal' to urban_renewal.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\usable.mp4...
# Extracted 35 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\usable.mp4.
# Augmenting frames...
# Augmented 35 frames.
# Assigned label 'usable' to usable.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\utility_trailer.mp4...
# Extracted 45 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\utility_trailer.mp4.
# Augmenting frames...
# Augmented 45 frames.
# Assigned label 'utility_trailer' to utility_trailer.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vacancy.mp4...
# Extracted 50 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vacancy.mp4.
# Augmenting frames...
# Augmented 50 frames.
# Assigned label 'vacancy' to vacancy.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\validation.mp4...
# Extracted 67 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\validation.mp4.
# Augmenting frames...
# Augmented 67 frames.
# Assigned label 'validation' to validation.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\varience.mp4...
# Extracted 95 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\varience.mp4.
# Augmenting frames...
# Augmented 95 frames.
# Assigned label 'varience' to varience.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_fleet.mp4...
# Extracted 117 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_fleet.mp4.
# Augmenting frames...
# Augmented 117 frames.
# Assigned label 'vehicle_fleet' to vehicle_fleet.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_insurance.mp4...
# Extracted 41 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_insurance.mp4.
# Augmenting frames...
# Augmented 41 frames.
# Assigned label 'vehicle_insurance' to vehicle_insurance.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_registration.mp4...
# Extracted 82 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vehicle_registration.mp4.
# Augmenting frames...
# Augmented 82 frames.
# Assigned label 'vehicle_registration' to vehicle_registration.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vessel_training.mp4...
# Extracted 44 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\vessel_training.mp4.
# Augmenting frames...
# Augmented 44 frames.
# Assigned label 'vessel_training' to vessel_training.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\viral.mp4...
# Extracted 56 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\viral.mp4.
# Augmenting frames...
# Augmented 56 frames.
# Assigned label 'viral' to viral.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\virtual_meeting.mp4...
# Extracted 35 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\virtual_meeting.mp4.
# Augmenting frames...
# Augmented 35 frames.
# Assigned label 'virtual_meeting' to virtual_meeting.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\waiver.mp4...
# Extracted 136 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\waiver.mp4.
# Augmenting frames...
# Augmented 136 frames.
# Assigned label 'waiver' to waiver.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\walkability.mp4...
# Extracted 89 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\walkability.mp4.
# Augmenting frames...
# Augmented 89 frames.
# Assigned label 'walkability' to walkability.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\warehouse.mp4...
# Extracted 65 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\warehouse.mp4.
# Augmenting frames...
# Augmented 65 frames.
# Assigned label 'warehouse' to warehouse.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\water_supply.mp4...
# Extracted 73 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\water_supply.mp4.
# Augmenting frames...
# Augmented 73 frames.
# Assigned label 'water_supply' to water_supply.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wayfinding.mp4...
# Extracted 80 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wayfinding.mp4.
# Augmenting frames...
# Augmented 80 frames.
# Assigned label 'wayfinding' to wayfinding.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wearable_assistive_devices.mp4...
# Extracted 83 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wearable_assistive_devices.mp4.
# Augmenting frames...
# Augmented 83 frames.
# Assigned label 'wearable_assistive_devices' to wearable_assistive_devices.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wearable_technology.mp4...
# Extracted 109 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wearable_technology.mp4.
# Augmenting frames...
# Augmented 109 frames.
# Assigned label 'wearable_technology' to wearable_technology.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\weaving_loom.mp4...
# Extracted 101 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\weaving_loom.mp4.
# Augmenting frames...
# Augmented 101 frames.
# Assigned label 'weaving_loom' to weaving_loom.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\web_accessibility.mp4...
# Extracted 74 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\web_accessibility.mp4.
# Augmenting frames...
# Augmented 74 frames.
# Assigned label 'web_accessibility' to web_accessibility.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\web_content_accessibility.mp4...
# Extracted 74 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\web_content_accessibility.mp4.
# Augmenting frames...
# Augmented 74 frames.
# Assigned label 'web_content_accessibility' to web_content_accessibility.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\weigh_station.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\weigh_station.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'weigh_station' to weigh_station.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wellness.mp4...
# Extracted 49 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wellness.mp4.
# Augmenting frames...
# Augmented 49 frames.
# Assigned label 'wellness' to wellness.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wharf.mp4...
# Extracted 42 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wharf.mp4.
# Augmenting frames...
# Augmented 42 frames.
# Assigned label 'wharf' to wharf.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel.mp4...
# Extracted 61 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel.mp4.
# Augmenting frames...
# Augmented 61 frames.
# Assigned label 'wheel' to wheel.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheelbase.mp4...
# Extracted 69 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheelbase.mp4.
# Augmenting frames...
# Augmented 69 frames.
# Assigned label 'wheelbase' to wheelbase.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheelchair_accessible_vehicle.mp4...
# Extracted 67 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheelchair_accessible_vehicle.mp4.
# Augmenting frames...
# Augmented 67 frames.
# Assigned label 'wheelchair_accessible_vehicle' to wheelchair_accessible_vehicle.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel_rim.mp4...
# Extracted 176 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel_rim.mp4.
# Augmenting frames...
# Augmented 176 frames.
# Assigned label 'wheel_rim' to wheel_rim.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel_wagon.mp4...
# Extracted 130 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wheel_wagon.mp4.
# Augmenting frames...
# Augmented 130 frames.
# Assigned label 'wheel_wagon' to wheel_wagon.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wide_area_network.mp4...
# Extracted 94 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wide_area_network.mp4.
# Augmenting frames...
# Augmented 94 frames.
# Assigned label 'wide_area_network' to wide_area_network.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wild_structure.mp4...
# Extracted 106 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wild_structure.mp4.
# Augmenting frames...
# Augmented 106 frames.
# Assigned label 'wild_structure' to wild_structure.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\window_of_car.mp4...
# Extracted 73 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\window_of_car.mp4.
# Augmenting frames...
# Augmented 73 frames.
# Assigned label 'window_of_car' to window_of_car.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\windshield.mp4...
# Extracted 107 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\windshield.mp4.
# Augmenting frames...
# Augmented 107 frames.
# Assigned label 'windshield' to windshield.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wings.mp4...
# Extracted 39 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wings.mp4.
# Augmenting frames...
# Augmented 39 frames.
# Assigned label 'wings' to wings.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wiper_of_car.mp4...
# Extracted 98 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wiper_of_car.mp4.
# Augmenting frames...
# Augmented 98 frames.
# Assigned label 'wiper_of_car' to wiper_of_car.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\worst.mp4...
# Extracted 73 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\worst.mp4.
# Augmenting frames...
# Augmented 73 frames.
# Assigned label 'worst' to worst.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wound_up.mp4...
# Extracted 52 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\wound_up.mp4.
# Augmenting frames...
# Augmented 52 frames.
# Assigned label 'wound_up' to wound_up.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xbox.mp4...
# Extracted 129 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xbox.mp4.
# Augmenting frames...
# Augmented 129 frames.
# Assigned label 'xbox' to xbox.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xylem.mp4...
# Extracted 136 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xylem.mp4.
# Augmenting frames...
# Augmented 136 frames.
# Assigned label 'xylem' to xylem.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xylophone.mp4...
# Extracted 85 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\xylophone.mp4.
# Augmenting frames...
# Augmented 85 frames.
# Assigned label 'xylophone' to xylophone.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\yaw_plane.mp4...
# Extracted 36 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\yaw_plane.mp4.
# Augmenting frames...
# Augmented 36 frames.
# Assigned label 'yaw_plane' to yaw_plane.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\yield.mp4...
# Extracted 68 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\yield.mp4.
# Augmenting frames...
# Augmented 68 frames.
# Assigned label 'yield' to yield.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zebra_crossing.mp4...
# Extracted 111 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zebra_crossing.mp4.
# Augmenting frames...
# Augmented 111 frames.
# Assigned label 'zebra_crossing' to zebra_crossing.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zero.mp4...
# Extracted 10 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zero.mp4.
# Augmenting frames...
# Augmented 10 frames.
# Assigned label 'zero' to zero.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zigzag.mp4...
# Extracted 42 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zigzag.mp4.
# Augmenting frames...
# Augmented 42 frames.
# Assigned label 'zigzag' to zigzag.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zinc_sheet.mp4...
# Extracted 134 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zinc_sheet.mp4.
# Augmenting frames...
# Augmented 134 frames.
# Assigned label 'zinc_sheet' to zinc_sheet.mp4.
# Extracting frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zoning_regulation.mp4...
# Extracted 197 frames from D:/Ace/7th sem files/1. REU/dataprep2blackout\zoning_regulation.mp4.
# Augmenting frames...
# Augmented 197 frames.
# Assigned label 'zoning_regulation' to zoning_regulation.mp4.
# Preprocessing complete.
# Data saved.

# %%
# labelling

# Create a label mapping
unique_labels = list(set(labels))
label_to_index = {label: idx for idx, label in enumerate(unique_labels)}

# Convert string labels to numerical labels
numerical_labels = [label_to_index[label] for label in labels]

import torch
from torch.utils.data import Dataset

class SignDataset(Dataset):
    def __init__(self, video_data, labels, transform=None, max_frames=100):
        self.video_data = video_data
        self.labels = labels
        self.transform = transform
        self.max_frames = max_frames

    def __len__(self):
        return len(self.video_data)

    def __getitem__(self, idx):
        video = self.video_data[idx]
        label = self.labels[idx]

        # Pad or truncate video to max_frames
        if len(video) < self.max_frames:
            padding = [torch.zeros_like(video[0])] * (self.max_frames - len(video))
            video.extend(padding)
        else:
            video = video[:self.max_frames]

        if self.transform:
            video = [self.transform(frame) for frame in video]
        video = torch.stack(video)
        label = torch.tensor(label, dtype=torch.long)  # Ensure label is a tensor of type long
        return video, label
    
# Model architecture

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models

class SignRecognitionModel(nn.Module):
    def __init__(self, num_classes):
        super(SignRecognitionModel, self).__init__()
        # Use a pre-trained 2D-CNN (e.g., ResNet) as the feature extractor
        self.cnn = models.resnet18(pretrained=True)
        self.cnn.fc = nn.Identity()  # Remove the final fully connected layer

        # LSTM to capture temporal relationships
        self.lstm = nn.LSTM(input_size=512, hidden_size=256, num_layers=2, batch_first=True)

        # Fully connected layer for classification
        self.fc = nn.Linear(256, num_classes)

    def forward(self, x):
        print("Forward pass started.")
        batch_size, seq_length, c, h, w = x.size()
        cnn_out = []

        # Pass each frame through the CNN
        for t in range(seq_length):
            frame = x[:, t, :, :, :]
            cnn_out.append(self.cnn(frame))
            print(f"Processed frame {t+1}/{seq_length} through CNN.")

        # Stack the CNN outputs and pass through LSTM
        cnn_out = torch.stack(cnn_out, dim=1)
        print("Stacked CNN outputs.")
        lstm_out, _ = self.lstm(cnn_out)
        print("Passed through LSTM.")

        # Take the output of the last LSTM cell
        lstm_out = lstm_out[:, -1, :]
        print("Extracted output from the last LSTM cell.")

        # Pass through the fully connected layer
        out = self.fc(lstm_out)
        print("Passed through the fully connected layer.")
        print("Forward pass completed.")
        return out


# query processing

import os
import torch
from transformers import BertTokenizer, BertModel
from sklearn.metrics.pairwise import cosine_similarity
import torch

# Load preprocessed data and labels
video_data = torch.load('video_data.pt', weights_only=True)
labels = torch.load('labels.pt', weights_only=True)

print("Data and labels loaded.")

import os

# Function to perform exact match
def exact_match(query, labels):
    if query in labels:
        index = labels.index(query)
        return video_data[index]
    else:
        return None




# Function to get BERT embeddings for a word
def get_bert_embedding(word):
    inputs = tokenizer(word, return_tensors='pt')
    outputs = bert_model(**inputs)
    return outputs.last_hidden_state.mean(dim=1).detach().numpy()

# Function to find the most similar word using BERT
def similar_word_search(query, labels):
    query_embedding = get_bert_embedding(query)
    label_embeddings = [get_bert_embedding(label) for label in labels]

    similarities = [cosine_similarity(query_embedding, label_embedding)[0][0] for label_embedding in label_embeddings]
    max_similarity_index = np.argmax(similarities)

    if similarities[max_similarity_index] > 0.7:  # Threshold for similarity
        return labels[max_similarity_index]
    else:
        return None



import torch

# Load the labels from the .pt file
labels_path = "labels.pt"  # Replace with the actual path to labels.pt
labels = torch.load(labels_path)

# Print the loaded labels
print(labels)



# # Example usage
# query = "butcher"
# labels = ["chef", "cook", "carpenter", "butcher"]  # Example dictionary of words

query = "butcher"

video_frames = exact_match(query, labels)

if not video_frames:
    print(f"Exact match not found for '{query}'. Searching for similar words...")
    similar_word = similar_word_search(query, labels)
    if similar_word:
        video_frames = exact_match(similar_word, labels)
        print(f"Similar word found: '{similar_word}', corresponding video frames retrieved.")
    else:
        print("No similar word found.")
else:
    print(f"Exact match found for '{query}', corresponding video frames retrieved.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 92
#      90 import os
#      91 import torch
# ---> 92 from transformers import BertTokenizer, BertModel
#      93 from sklearn.metrics.pairwise import cosine_similarity
#      94 import torch
#
# ModuleNotFoundError: No module named 'transformers'
